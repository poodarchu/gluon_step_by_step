# %%
from mxnet import image

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
img = image.imdecode(open('/Users/poodar/Pictures/Wallpapers/fox-in-the-field-3440x1440.jpg', 'rb').read())
plt.imshow(img.asnumpy())
